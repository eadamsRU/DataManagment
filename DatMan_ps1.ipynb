# %% [markdown]
# <a href="https://colab.research.google.com/github/eadamsRU/DataManagment/blob/main/DatMan_ps1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import csv
import xml
import json
import pandas as pd
# !wget -q -O crash.csv https://docs.google.com/spreadsheets/d/1d-zuC77iI_NWfj_T-hH39VSgxHX_FCim2TnGuyqchZU/edit?usp=drive_link&export=download
#!wget -q -O electricFire.xml https://en.wikipedia.org/wiki/Plug-in_electric_vehicle_fire_incidents&export=download
#!wget -q -O NbaPO.json https://docs.google.com/document/d/1JUD_LuXmEMTw4YNMaeaO9UyQgGbAhrBrT3nAsRjSu7c/edit&export=download

#dat=pd.read_csv('crash.csv')
#dat = pd.read_csv('crash.csv')

# %%
import csv
import xml
import json
import pandas as pd

# !wget -q -O electricFire.xml https://en.wikipedia.org/wiki/Plug-in_electric_vehicle_fire_incidents&export=download

# %%
import csv
import xml
import json
import pandas as pd

# !wget -q -O NbaPO.json https://docs.google.com/document/d/1JUD_LuXmEMTw4YNMaeaO9UyQgGbAhrBrT3nAsRjSu7c/edit&export=download

# %% [markdown]
# This reads in the 3 files in 3 different file formats

# %%
import pandas as pd

#dat = pd.read_csv('crash.csv')
dat1 = pd.read_csv('crash.csv', on_bad_lines='skip')

#dat1
#dat2 = pd.read_xml('electricFire.xml')
#dat3 = pd.read_json('NbaPO.json')

dat1.head(5)
# Out:
#   <!doctype html><html lang="en-US" dir="ltr"><head><base href="https://accounts.google.com/v3/signin/"><meta name="referrer" content="origin"><meta name="viewport" content="width=device-width  \
# 0                                           --c-brsz
# 1    )}.bEbGY{-webkit-box-pack:center;-webkit-jus...
# 2                                           --c-brsz
# 3    )}.no7ij{display:-webkit-box;display:-webkit...
# 4                                           --c-brsz
#
#    initial-scale=1"><style data-href="https://www.gstatic.com/_/mss/boq-identity/_/ss/k=boq-identity.AccountsSignInUi.Vjr82SOSFTI.L.W.O/am=hhwAIiYeY4DyH0AACAAUKAAAAAAAAAAAAg2XEA/d=1/ed=1/rs=AOaEmlE90XE6m4Ek-mIW72VWHccGpLqf8w/m=identifierview  \
# 0                                               48px
# 1                                                NaN
# 2                                               48px
# 3  #0b57d0)}.Qk3oof.WS4XDd{border:0;max-height:1....
# 4                                               48px
#
#     _b  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#   _tp" nonce="mcz_dSjr1l0aSVC7NZh-Bg">c-wiz{contain:style}c-wiz>c-data{display:none}c-wiz.rETSD{contain:none}c-wiz.Ubi8Z{contain:layout style}@-webkit-keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   -50%) scale(0.2);-webkit-transform:translate(-50%  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   -50%) scale(0.2);transform:translate(-50%  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   -50%) scale(0.2)}to{-webkit-transform:translate(-50%  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   -50%) scale(2.2);-webkit-transform:translate(-50%  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   -50%) scale(2.2);transform:translate(-50%  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#   -50%) scale(2.2)}}@keyframes quantumWizBoxInkSpread{0%{-webkit-transform:translate(-50%  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ...  \
# 0  ...
# 1  ...
# 2  ...
# 3  ...
# 4  ...
#
#   .BDEI9:after{-webkit-box-flex:1;box-flex:1;-webkit-flex-grow:1;flex-grow:1;content:"";height:24px}.BDEI9:before{min-height:30px}.BDEI9:after{min-height:24px}.BDEI9.LZgQXe:after{min-height:63.9996px}}.gEc4r{display:-webkit-box;display:-webkit-flex;display:flex;height:24px;-webkit-justify-content:center;justify-content:center}.gEc4r.jlqJKb{height:auto;min-height:24px;padding-top:24px}.BivnM{-webkit-align-items:center;align-items:center;border-bottom:1px solid #ccc;display:-webkit-box;display:-webkit-flex;display:flex;height:36px;left:0;padding:0 16px;position:absolute;right:0;top:0}.BivnM .ji6sFc{height:14px;margin-right:12px}.O3jdWc{color:rgb(95  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   99.2  \
# 0  NaN
# 1  NaN
# 2  NaN
# 3  NaN
# 4  NaN
#
#   104);font-size:14px;height:14px;margin-top:-2px}.Zwk8S{display:block;height:37px;width:37px}.wFNE4e{color:rgb(26  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   115.8 232)}:root{--wf-tfs:calc(var(--c-tfs  \
# 0   NaN                                  NaN
# 1   NaN                                  NaN
# 2   NaN                                  NaN
# 3   NaN                                  NaN
# 4   NaN                                  NaN
#
#   32)/16*1rem);--wf-tfs-bp3:calc(var(--c-tfs  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   36)/16*1rem);--wf-tfs-bp5:calc(var(--c-tfs  \
# 0                                        NaN
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#   44)/16*1rem);--wf-stfs:calc(var(--c-stfs  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#   16)/16*1rem);--wf-stfs-bp5:calc(var(--c-stfs  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   18)/16*1rem)}.Wf6lSd{display:-webkit-box;display:-webkit-flex;display:flex;-webkit-box-pack:start;-webkit-justify-content:flex-start;justify-content:flex-start;height:48px;height:var(
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
# [5 rows x 153 columns]

# %%
import urllib.request

req = urllib.request.Request('https://docs.google.com/spreadsheets/d/1d-zuC77iI_NWfj_T-hH39VSgxHX_FCim2TnGuyqchZU/edit#gid=563254551')
req.head(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-d057d66a5c73> in <cell line: 4>()
#       2
#       3 req = urllib.request.Request('https://docs.google.com/spreadsheets/d/1d-zuC77iI_NWfj_T-hH39VSgxHX_FCim2TnGuyqchZU/edit#gid=563254551')
# ----> 4 req.head(2)
#
# AttributeError: 'Request' object has no attribute 'head'

# %%
import pandas as pd
tables=pd.read_html('https://en.wikipedia.org/wiki/List_of_counties_in_New_Jersey')
             #,attrs = {'id': 'List_of_counties'})
#,match='Density',flavor=None)[0].head(3)

# %%
tables[3].head(2)
# Out:
#   vteState of New Jersey                           vteState of New Jersey.1
# 0      Trenton (capital)                                  Trenton (capital)
# 1                 Topics  Index Geography climate climate change Governm...
