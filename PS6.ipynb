# %% [markdown]
# <a href="https://colab.research.google.com/github/eadamsRU/DataManagment/blob/main/PS6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# aok dec6 oveall good on the right track, just need couple things more, beef it up a bit--there's a ton of others notebooks doing mba:
# https://www.google.com/search?client=firefox-b-1-d&q=python+notebook+basketball+analysis

# %% [markdown]
# # PS6/ Final Project Rough Draft

# %% [markdown]
# I want to see based on last years stats of the 76ers what they needed to make for offseason moves to help them out for the follow year. Some insights for a team would be a low Minutes per game player with a higher 3 PT%. See what would be available in the current NBA population to sift through and see how other players would benefit after seeing their stats merged onto a hypothetical 76ers roster and see if it improves team overall.
#
# *   Need to also incorporate player wages/contracts to see this as well
#
# Think most of the charts I want to use/ have an idea of where I want to clean up my data to illustrate hardpoints this team was lacking

# %%
import csv

# !wget -q -O NBA.csv https://raw.githubusercontent.com/eadamsRU/DataManagment/main/NBA%202022-23%20Player%20Stats.csv
# !wget -q -O 76ers.csv https://raw.githubusercontent.com/eadamsRU/DataManagment/main/NBA%202022-2023%2076ers%20Per%20Game%20Stats.csv

# %%
import pandas as pd
NBA_76ers = pd.read_csv('76ers.csv', encoding='unicode_escape')
NBA = pd.read_csv('NBA.csv', encoding='unicode_escape')

# %% [markdown]
# Want to find the whole NBA population who has above a 40% 3-point percentage and do comparison with other stats, such as minutes, rebounds and steals

# %%
NBA_3percentage = NBA['3P%'] >= .4

# %%
NBA_3percentage
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 535    False
# 536    False
# 537    False
# 538    False
# 539    False
# Name: 3P%, Length: 540, dtype: bool

# %%
Top30 =NBA.head(30)
Top30
# Out:
#       Rk                   Player    Pos   Age   Tm     G    GS      MP  \
# 0    1.0             Jayson Tatum     SF  24.0  BOS  74.0  74.0  2732.0
# 1    2.0              Joel Embiid      C  28.0  PHI  66.0  66.0  2284.0
# 2    3.0              Luka Don_i_     PG  23.0  DAL  66.0  66.0  2391.0
# 3    4.0  Shai Gilgeous-Alexander     PG  24.0  OKC  68.0  68.0  2416.0
# 4    5.0    Giannis Antetokounmpo     PF  28.0  MIL  63.0  63.0  2024.0
# 5    6.0          Anthony Edwards     SG  21.0  MIN  79.0  79.0  2842.0
# 6    7.0            Julius Randle     PF  28.0  NYK  77.0  77.0  2737.0
# 7    8.0         Donovan Mitchell     SG  26.0  CLE  68.0  68.0  2432.0
# 8    9.0               Trae Young     PG  24.0  ATL  73.0  73.0  2541.0
# 9   10.0              Zach LaVine     SG  27.0  CHI  77.0  77.0  2768.0
# 10  11.0           Damian Lillard     PG  32.0  POR  58.0  58.0  2107.0
# 11  12.0             De'Aaron Fox     PG  25.0  SAC  73.0  73.0  2435.0
# 12  13.0            DeMar DeRozan     SF  33.0  CHI  74.0  74.0  2682.0
# 13  14.0             Jaylen Brown     SF  26.0  BOS  67.0  67.0  2405.0
# 14  15.0            Pascal Siakam     PF  28.0  TOR  71.0  71.0  2652.0
# 15  16.0          Lauri Markkanen     PF  25.0  UTA  66.0  66.0  2273.0
# 16  17.0             Nikola Joki_      C  27.0  DEN  69.0  69.0  2323.0
# 17  18.0              Jalen Green     SG  20.0  HOU  76.0  76.0  2602.0
# 18  19.0             Jordan Poole     PG  23.0  GSW  82.0  43.0  2458.0
# 19  20.0            Mikal Bridges  SF-SG  26.0  TOT  83.0  83.0  2963.0
# 20  21.0            Stephen Curry     PG  34.0  GSW  56.0  56.0  1941.0
# 21  22.0            Jalen Brunson     PG  26.0  NYK  68.0  68.0  2379.0
# 22  23.0             Kyrie Irving  PG-SG  30.0  TOT  60.0  60.0  2241.0
# 23  24.0                Ja Morant     PG  23.0  MEM  61.0  59.0  1948.0
# 24  25.0             LeBron James     PF  38.0  LAL  55.0  54.0  1954.0
# 25  26.0              CJ McCollum     SG  31.0  NOP  75.0  75.0  2649.0
# 26  27.0              Bam Adebayo      C  25.0  MIA  75.0  75.0  2598.0
# 27  28.0          Dejounte Murray     SG  26.0  ATL  74.0  74.0  2693.0
# 28  29.0         Domantas Sabonis      C  26.0  SAC  79.0  79.0  2736.0
# 29  30.0            Klay Thompson     SF  32.0  GSW  69.0  69.0  2279.0
#
#        FG     FGA  ...    FT%    ORB    DRB    TRB    AST    STL    BLK  \
# 0   727.0  1559.0  ...  0.854   78.0  571.0  649.0  342.0   78.0   51.0
# 1   728.0  1328.0  ...  0.857  113.0  557.0  670.0  274.0   66.0  112.0
# 2   719.0  1449.0  ...  0.742   54.0  515.0  569.0  529.0   90.0   33.0
# 3   704.0  1381.0  ...  0.905   59.0  270.0  329.0  371.0  112.0   65.0
# 4   707.0  1278.0  ...  0.645  137.0  605.0  742.0  359.0   52.0   51.0
# 5   707.0  1541.0  ...  0.756   47.0  411.0  458.0  350.0  125.0   58.0
# 6   658.0  1432.0  ...  0.757  141.0  626.0  767.0  316.0   49.0   21.0
# 7   679.0  1402.0  ...  0.867   63.0  226.0  289.0  301.0   99.0   27.0
# 8   597.0  1390.0  ...  0.886   56.0  161.0  217.0  741.0   80.0    9.0
# 9   673.0  1388.0  ...  0.848   42.0  303.0  345.0  327.0   69.0   18.0
# 10  556.0  1202.0  ...  0.914   44.0  233.0  277.0  425.0   50.0   18.0
# 11  682.0  1331.0  ...  0.780   40.0  266.0  306.0  447.0   83.0   23.0
# 12  657.0  1303.0  ...  0.872   34.0  309.0  343.0  377.0   83.0   36.0
# 13  679.0  1383.0  ...  0.765   78.0  381.0  459.0  232.0   75.0   26.0
# 14  630.0  1313.0  ...  0.774  131.0  425.0  556.0  415.0   65.0   36.0
# 15  571.0  1145.0  ...  0.875  130.0  440.0  570.0  123.0   42.0   38.0
# 16  646.0  1022.0  ...  0.822  167.0  650.0  817.0  678.0   87.0   47.0
# 17  566.0  1359.0  ...  0.786   43.0  241.0  284.0  281.0   59.0   18.0
# 18  550.0  1278.0  ...  0.870   32.0  193.0  225.0  369.0   63.0   21.0
# 19  593.0  1267.0  ...  0.895   79.0  285.0  364.0  273.0   91.0   61.0
# 20  559.0  1133.0  ...  0.915   39.0  302.0  341.0  352.0   52.0   20.0
# 21  587.0  1195.0  ...  0.829   40.0  201.0  241.0  421.0   61.0   15.0
# 22  594.0  1203.0  ...  0.905   59.0  245.0  304.0  331.0   66.0   45.0
# 23  566.0  1214.0  ...  0.748   61.0  296.0  357.0  493.0   66.0   16.0
# 24  609.0  1219.0  ...  0.768   65.0  392.0  457.0  375.0   50.0   32.0
# 25  587.0  1344.0  ...  0.769   55.0  273.0  328.0  429.0   70.0   38.0
# 26  602.0  1114.0  ...  0.806  184.0  504.0  688.0  240.0   88.0   61.0
# 27  612.0  1319.0  ...  0.832   53.0  336.0  389.0  448.0  112.0   19.0
# 28  577.0   938.0  ...  0.742  251.0  722.0  973.0  573.0   65.0   39.0
# 29  546.0  1252.0  ...  0.879   39.0  247.0  286.0  163.0   49.0   29.0
#
#       TOV     PF    PTS_
# 0   213.0  160.0  2225.0
# 1   226.0  205.0  2183.0
# 2   236.0  166.0  2138.0
# 3   192.0  192.0  2135.0
# 4   246.0  197.0  1959.0
# 5   259.0  186.0  1946.0
# 6   216.0  233.0  1936.0
# 7   180.0  168.0  1922.0
# 8   300.0  104.0  1914.0
# 9   194.0  159.0  1913.0
# 10  191.0  109.0  1866.0
# 11  181.0  172.0  1826.0
# 12  153.0  186.0  1816.0
# 13  197.0  172.0  1784.0
# 14  169.0  228.0  1720.0
# 15  127.0  137.0  1691.0
# 16  247.0  174.0  1690.0
# 17  200.0  131.0  1683.0
# 18  252.0  214.0  1675.0
# 19  127.0  159.0  1671.0
# 20  179.0  117.0  1648.0
# 21  142.0  152.0  1633.0
# 22  128.0  165.0  1623.0
# 23  206.0  100.0  1596.0
# 24  178.0   88.0  1590.0
# 25  183.0  153.0  1568.0
# 26  187.0  208.0  1529.0
# 27  160.0  106.0  1515.0
# 28  230.0  279.0  1510.0
# 29  123.0  130.0  1509.0
#
# [30 rows x 30 columns]

# %%
NBA_76ers.head(3)
# Out:
#    Rk        Player  Age   G  GS    MP    FG   FGA    FG%   3P  ...    FT%  \
# 0   1  James Harden   33  58  58  36.8   6.4  14.5  0.441  2.8  ...  0.867
# 1   2   Joel Embiid   28  66  66  34.6  11.0  20.1  0.548  1.0  ...  0.857
# 2   3  Tyrese Maxey   22  60  41  33.6   7.3  15.2  0.481  2.7  ...  0.845
#
#    ORB  DRB   TRB   AST  STL  BLK  TOV   PF   PTS
# 0  0.7  5.4   6.1  10.7  1.2  0.5  3.4  1.9  21.0
# 1  1.7  8.4  10.2   4.2  1.0  1.7  3.4  3.1  33.1
# 2  0.4  2.6   2.9   3.5  0.8  0.1  1.3  2.2  20.3
#
# [3 rows x 28 columns]

# %%
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Graphs

# %% [markdown]
# want to update:
#
#
# *   Sizing
# *   Color scale to match team?
# *   Change the symbols and the legend as well
#
# want to incorporate a comparison between another or all teams

# %% [markdown]
# ***Scatter plots may help to show any 2 stats ***

# %% [markdown]
# Added the size based on FGA to see which players are putting up more shots and it makes sense that players who are on the court more are scoring and putting up more shots

# %%
import plotly.express as px

fig = px.scatter(NBA_76ers, x="MP", y="PTS",symbol='Player', size = 'FGA',color="Rk",
                 width=1000,height=600)
fig.update_layout(legend=dict(yanchor="top",xanchor="right"),
    title_text = '76ers 2022-2023 Points per Minute')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cf377212-00b4-415b-b526-942f56f2b83c" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cf377212-00b4-415b-b526-942f56f2b83c")) {                    Plotly.newPlot(                        "cf377212-00b4-415b-b526-942f56f2b83c",                        [{"hovertemplate":"Player=James Harden\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"James Harden","marker":{"color":[1],"coloraxis":"coloraxis","size":[14.5],"sizemode":"area","sizeref":0.05025,"symbol":"circle"},"mode":"markers","name":"James Harden","orientation":"v","showlegend":true,"x":[36.8],"xaxis":"x","y":[21.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Joel Embiid\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Joel Embiid","marker":{"color":[2],"coloraxis":"coloraxis","size":[20.1],"sizemode":"area","sizeref":0.05025,"symbol":"diamond"},"mode":"markers","name":"Joel Embiid","orientation":"v","showlegend":true,"x":[34.6],"xaxis":"x","y":[33.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Tyrese Maxey\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tyrese Maxey","marker":{"color":[3],"coloraxis":"coloraxis","size":[15.2],"sizemode":"area","sizeref":0.05025,"symbol":"square"},"mode":"markers","name":"Tyrese Maxey","orientation":"v","showlegend":true,"x":[33.6],"xaxis":"x","y":[20.3],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Tobias Harris\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tobias Harris","marker":{"color":[4],"coloraxis":"coloraxis","size":[11.4],"sizemode":"area","sizeref":0.05025,"symbol":"x"},"mode":"markers","name":"Tobias Harris","orientation":"v","showlegend":true,"x":[32.9],"xaxis":"x","y":[14.7],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Louis King\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Louis King","marker":{"color":[5],"coloraxis":"coloraxis","size":[13.0],"sizemode":"area","sizeref":0.05025,"symbol":"cross"},"mode":"markers","name":"Louis King","orientation":"v","showlegend":true,"x":[29.0],"xaxis":"x","y":[20.0],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=De'Anthony Melton\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"De'Anthony Melton","marker":{"color":[6],"coloraxis":"coloraxis","size":[8.5],"sizemode":"area","sizeref":0.05025,"symbol":"circle"},"mode":"markers","name":"De'Anthony Melton","orientation":"v","showlegend":true,"x":[27.9],"xaxis":"x","y":[10.1],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=P.J. Tucker\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P.J. Tucker","marker":{"color":[7],"coloraxis":"coloraxis","size":[3.0],"sizemode":"area","sizeref":0.05025,"symbol":"diamond"},"mode":"markers","name":"P.J. Tucker","orientation":"v","showlegend":true,"x":[25.6],"xaxis":"x","y":[3.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Shake Milton\u003cbr\u003eMP=%{x}\u003cbr\u003ePTS=%{y}\u003cbr\u003eFGA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cex ...

# %%
fig76ers_3s = px.scatter(NBA_76ers, x="MP", y="3P%",symbol='Player', size = '3PA',color="Rk",
                 width=1000,height=600)
fig76ers_3s.update_layout(legend=dict(yanchor="top",xanchor="right"),
    title_text = '76ers 2022-2023 3 Points per Minute')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="3f5591e4-9d61-46cd-8a4d-0e5b0730cce8" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f5591e4-9d61-46cd-8a4d-0e5b0730cce8")) {                    Plotly.newPlot(                        "3f5591e4-9d61-46cd-8a4d-0e5b0730cce8",                        [{"hovertemplate":"Player=James Harden\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"James Harden","marker":{"color":[1],"coloraxis":"coloraxis","size":[7.2],"sizemode":"area","sizeref":0.02,"symbol":"circle"},"mode":"markers","name":"James Harden","orientation":"v","showlegend":true,"x":[36.8],"xaxis":"x","y":[0.385],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Joel Embiid\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Joel Embiid","marker":{"color":[2],"coloraxis":"coloraxis","size":[3.0],"sizemode":"area","sizeref":0.02,"symbol":"diamond"},"mode":"markers","name":"Joel Embiid","orientation":"v","showlegend":true,"x":[34.6],"xaxis":"x","y":[0.33],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Tyrese Maxey\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tyrese Maxey","marker":{"color":[3],"coloraxis":"coloraxis","size":[6.2],"sizemode":"area","sizeref":0.02,"symbol":"square"},"mode":"markers","name":"Tyrese Maxey","orientation":"v","showlegend":true,"x":[33.6],"xaxis":"x","y":[0.434],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Tobias Harris\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Tobias Harris","marker":{"color":[4],"coloraxis":"coloraxis","size":[4.4],"sizemode":"area","sizeref":0.02,"symbol":"x"},"mode":"markers","name":"Tobias Harris","orientation":"v","showlegend":true,"x":[32.9],"xaxis":"x","y":[0.389],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Louis King\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Louis King","marker":{"color":[5],"coloraxis":"coloraxis","size":[8.0],"sizemode":"area","sizeref":0.02,"symbol":"cross"},"mode":"markers","name":"Louis King","orientation":"v","showlegend":true,"x":[29.0],"xaxis":"x","y":[0.5],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=De'Anthony Melton\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"De'Anthony Melton","marker":{"color":[6],"coloraxis":"coloraxis","size":[5.2],"sizemode":"area","sizeref":0.02,"symbol":"circle"},"mode":"markers","name":"De'Anthony Melton","orientation":"v","showlegend":true,"x":[27.9],"xaxis":"x","y":[0.39],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=P.J. Tucker\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P.J. Tucker","marker":{"color":[7],"coloraxis":"coloraxis","size":[1.9],"sizemode":"area","sizeref":0.02,"symbol":"diamond"},"mode":"markers","name":"P.J. Tucker","orientation":"v","showlegend":true,"x":[25.6],"xaxis":"x","y":[0.393],"yaxis":"y","type":"scatter"},{"hovertemplate":"Player=Shake Milton\u003cbr\u003eMP=%{x}\u003cbr\u003e3P%=%{y}\u003cbr\u003e3PA=%{marker.size}\u003cbr\u003eRk=%{marker.color}\u003cextra\u003e\u003c\u002fe ...

# %% [markdown]
# This is showing size for Offensive Rebounds, which are more challenging to get compared to a defensive rebound. So a good insight into what players help get second chance oppurtunity and possibly figure out which rotations to use in the future if you have shooters trying to score from 3.

# %%
fig76ers_boards = px.scatter(NBA_76ers, x="MP", y="TRB",symbol='Player', size = 'ORB',color="Rk",
                 width=1000,height=600)
fig76ers_boards.update_layout(legend=dict(yanchor="top",xanchor="right"),
    title_text = '76ers 2022-2023 Rebounds per Minute')

# %% [markdown]
# ***Bar Graphs***

# %% [markdown]
# Add a bar graph to show players with <= 17.5 MPG and with a minimum .4 3P%

# %%
fig3s = px.bar()

# %%
figa = px.bar(Top30, x = 'Player', y = 'PTS_')
figa.show()

# %%
'''df = px.data.iris()
fig = px.scatter_matrix(auto,
    dimensions=["weight", "length", "price", "mpg"],
    color="foreign", #symbol="trunk",
    title="can brush select",
    hover_data=['make'])
fig.update_traces(diagonal_visible=False)'''

# %%
'''df = px.data.gapminder().query("year == 2007")
fig = px.treemap(df, path=[px.Constant("world"), 'continent', 'country'], values='pop',
                  color='lifeExp', hover_data=['iso_alpha'],
                  color_continuous_scale='RdBu',
                  color_continuous_midpoint=np.average(df['lifeExp'], weights=df['pop']))
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))'''

# %%
fig2 = px.treemap(NBA_76ers,path=['Player'], values= 'FG%')
fig2.show()

# %%
NBA_76ers.head(3)

# %% [markdown]
# # Individual Player Analysis

# %% [markdown]
# This would be another great graph below I would like to implement more so for specific player stats, as this is used a lot in sports analytics.
#
# Could still be used/ may be easier to represent for a team
#
# **Want to show this as just single player 'filter' Show in a clear quick way what players strong suits are**

# %% [markdown]
# Can just plug in player name and do a side by side analysis.
# Overlay? have player a be red player b be blue.
#
# See similarities and differences that way

# %%
import plotly.express as px
import pandas as pd
spider = pd.DataFrame(dict(
    r=['James Harden'],
    theta=['MP','FG%','FG','3P%', '3P', 'TRB', 'AST']))
fig3 = px.line_polar(spider, r='r', theta='theta', line_close=True)
fig3.update_traces(fill='toself')
fig3.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-152ff35cca67> in <cell line: 3>()
#       1 import plotly.express as px
#       2 import pandas as pd
# ----> 3 spider = pd.DataFrame(dict(
#       4     r=['James Harden'],
#       5     theta=['MP','FG%','FG','3P%', '3P', 'TRB', 'AST']))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     662         elif isinstance(data, dict):
#     663             # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 664             mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     665         elif isinstance(data, ma.MaskedArray):
#     666             import numpy.ma.mrecords as mrecords
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in dict_to_mgr(data, index, columns, dtype, typ, copy)
#     491             arrays = [x.copy() if hasattr(x, "dtype") else x for x in arrays]
#     492
# --> 493     return arrays_to_mgr(arrays, columns, index, dtype=dtype, typ=typ, consolidate=copy)
#     494
#     495
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in arrays_to_mgr(arrays, columns, index, dtype, verify_integrity, typ, consolidate)
#     116         # figure out the index, if necessary
#     117         if index is None:
# --> 118             index = _extract_index(arrays)
#     119         else:
#     120             index = ensure_index(index)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/internals/construction.py in _extract_index(data)
#     664             lengths = list(set(raw_lengths))
#     665             if len(lengths) > 1:
# --> 666                 raise ValueError("All arrays must be of the same length")
#     667
#     668             if have_dicts:
#
# ValueError: All arrays must be of the same length

# %%
# radar or spider web https://plotly.com/python/radar-chart/
categories = ['MP','FG%','FG',
              '3P%', '3P', 'TRB', 'AST']

fig3 = go.Figure()

fig3.add_trace(go.Scatterpolar(
      r=[1, 5, 2, 2, 3],
      theta=categories,
      fill='toself',
      name='Product A'
))
fig3.add_trace(go.Scatterpolar(
      r=[4, 3, 2.5, 1, 2],
      theta=categories,
      fill='toself',
      name='Product B'
))

fig.update_layout(
  polar=dict(
    radialaxis=dict(
      visible=True,
      range=[0, 5]
    )),
  showlegend=False
)

# %% [markdown]
# **Below was from PS5, Most likely will not include in final draft, but good for the future if I want to expand this notebook:**

# %% [markdown]
# Future stats tracked:
#
# NBA analytics has become increasingly crucial in understanding player performance, team dynamics, and overall game strategies. Several key metrics are worth tracking to gain comprehensive insights into a team's and players' effectiveness. Here are some essential areas of focus:
#
# Player Efficiency Rating (PER):
# PER is a comprehensive metric that evaluates a player's overall impact on the game, considering various statistics like scoring efficiency, rebounding, and playmaking.
#
# True Shooting Percentage (TS%):
# TS% provides a more accurate representation of a player's scoring efficiency by incorporating two-point field goals, three-pointers, and free throws.
#
# Effective Field Goal Percentage (eFG%):
# eFG% adjusts traditional field goal percentage to account for the added value of three-pointers, providing a more complete picture of a player's shooting effectiveness.
#
# Offensive and Defensive Rating:
# These metrics evaluate a team's performance on offense and defense per 100 possessions, offering insights into their efficiency and effectiveness at both ends of the court.
#
# Box Plus-Minus (BPM):
# BPM combines box score statistics to estimate a player's overall impact per 100 possessions, encompassing offense, defense, and overall contributions.
#
# Usage Rate:
# Usage Rate measures the percentage of a team's possessions that a player uses while on the court, helping to identify primary offensive contributors.
#
# Assist-to-Turnover Ratio:
# This ratio assesses a player's ability to create scoring opportunities through assists while minimizing turnovers, highlighting their playmaking efficiency.
#
# Rebound Percentage:
# Rebound Percentage calculates the proportion of available rebounds a player grabs, providing insights into their rebounding prowess relative to their playing time.
#
# Pace:
# Pace measures the number of possessions a team or player averages per game, influencing the tempo and style of play.
#
# Shot Charts:
# Analyzing shot charts helps understand a player's shooting tendencies, strengths, and weaknesses from different areas on the court, aiding in strategic planning.
#
# On/Off Court Net Rating:
# Comparing a team's performance with a player on and off the court helps gauge their impact on team success.
#
# Clutch Performance:
# Examining a player's or team's performance in clutch situations (close games in the final minutes) provides insights into their ability to perform under pressure.

# %% [markdown]
# # Sources

# %% [markdown]
# *  https://www.basketball-reference.com/
#
#
# Final draft sources:
#
# *  https://hoopshype.com/salaries/
# *  https://sportradar.com/?lang=en-us

# %% [markdown]
# Things to add
#
# *   Salary
# *   Possibly specify in NBA population if someone was going into a free agency the following season
# *   Compare with an 'Average' NBA team and see how the 76ers looked across the league

# %% [markdown]
# Want to deetermine if It makes sense to merge the salaries DF I will make to the NBA DF, or to just add it as an additional one and do separate graphs
